# %%
import sys
sys.path=['/python-modules']+sys.path

import eternann.puzzles
with open("/data/puzzles/eterna100_benchmark.txt", "r") as f:
    puzzles = eternann.puzzles.parse(f)
    
puzzles
# Out:
# > /python-modules/eternann/puzzles.py(14)parse()
# -> rows.append(row)
# (Pdb) c
# [{'name': 'Simple Hairpin',
#   'eterna_id': '20111',
#   'author': 'Sneh',
#   'secondary_structure': '(((((......)))))'},
#  {'name': 'Arabidopsis Thaliana 6 RNA - Difficulty Level 0',
#   'eterna_id': '215430',
#   'author': 'Sneh',
#   'secondary_structure': '(((((((....(((...........)))((((((((..(((((((((((((((((((...(((((......))))).)))))).)))))))))))))..))))))))..)))))))'},
#  {'name': 'Prion Pseudoknot - Difficulty Level 0',
#   'eterna_id': '15819',
#   'author': 'Sneh',
#   'secondary_structure': '((((((.((((....))))))).)))..........'},
#  {'name': 'Human Integrated Adenovirus - Difficulty Level 0',
#   'eterna_id': '15886',
#   'author': 'Sneh',
#   'secondary_structure': '((((((((((((((.((((((...........((((((((((((.....((((((((....(((((((((((((........))))))))))....))))))))....))))))....)))))...((((((.......))))))))))............)))))).))))....))))))...))))...'},
# ...
